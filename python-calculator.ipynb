# %%
def add(num1, num2):
    return num1 + num2

def subtract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def division(num1, num2):
    return num1 / num2

def modulus(num1, num2):
    return num1 % num2

print("Please select one of these operators according to your choice:\n"
      "1. ADDITION\n"
      "2. SUBTRACTION\n"
      "3. MULTIPLICATION\n"
      "4. DIVISION\n"
      "5. MODULUS\n")

select = int(input("SELECT ONE OF YOUR CHOICE:"))

number_1 = int(input("ENTER YOUR FIRST NUMBER:"))
number_2 = int(input("ENTER YOUR SECOND NUMBER:"))

if select == 1:
    print(number_1, "+", number_2, "=", add(number_1, number_2))
elif select == 2:
    print(number_1, "-", number_2, "=", subtract(number_1, number_2))
elif select == 3:
    print(number_1, "*", number_2, "=", multiply(number_1, number_2))
elif select == 4:
    print(number_1, "/", number_2, "=", division(number_1, number_2))
elif select == 5:
    print(number_1, "%", number_2, "=", modulus(number_1, number_2))
else:
    print("YOU HAVE ENTERED THE WRONG CHOICE, PLEASE TRY AGAIN LATER:")
# Out:
# Please select one of these operators according to your choice:
# 1. ADDITION
# 2. SUBTRACTION
# 3. MULTIPLICATION
# 4. DIVISION
# 5. MODULUS
# SELECT ONE OF YOUR CHOICE: 2
# ENTER YOUR FIRST NUMBER: 30000
# ENTER YOUR SECOND NUMBER: 4900
# 30000 - 4900 = 25100
