# %%
import random
rock='''
    --------
----  ------)
      (-----)
      (-----)
      (-----)
----- ------     
    '''
paper='''
   ------
---  ---)---)   
     --------)
     --------)
     --------)
     --------)
---  ---(---)
   '''
scissors='''
   ------
---   ---)---)
      -------)
   ----------)
   (----)
---(---)
'''

#let's take out the user's choice:"
image_show=[rock,paper,scissors]
user_choice=int(input("Enter your choice: Type 0 for rock, 1 for paper, 2 for scissors."))

if user_choice>=3 or user_choice<0:
    print("You  entered a invalid number , you will loose.")
else:
    print(image_show[user_choice])
    computer_choice=random.randint(0,2)
    print("This is an computer choice:")
    print(image_show[computer_choice])
    print(computer_choice)
    if computer_choice==user_choice:
        print("It is a draw.")
    elif computer_choice==0 and user_choice==2:
        print("You loose the game:")
    elif user_choice==0 and computer_choice==2:
        print("You win the game:")
    elif computer_choice>user_choice:
        print("You will loose:")
    elif user_choice>computer_choice:
        print("You will win:")
# Out:
# Enter your choice: Type 0 for rock, 1 for paper, 2 for scissors. 0
#     --------
# ----  ------)
#       (-----)
#       (-----)
#       (-----)
# ----- ------
#
# This is an computer choice:
#
#     --------
# ----  ------)
#       (-----)
#       (-----)
#       (-----)
# ----- ------
#
# 0
# It is a draw.
